# %%
import os
import pandas as pd
import SimpleITK as sitk
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import ImageViewer as iv
import get_data as gd
import Preprocessing as p
import preprocessing_franziska as pf
from matplotlib.ticker import MaxNLocator, FixedLocator, FixedFormatter

# %%
LARC_patientPaths, LARC_PatientNames, LARC_imagePaths, LARC_maskPaths = gd.get_paths('/Volumes/HARDDISK/MasterThesis/LARC_cropped', 'image', 'label.nii')
Oxy_patientPaths, Oxy_PatientNames, Oxy_imagePaths, Oxy_maskPaths = gd.get_paths('/Volumes/HARDDISK/MasterThesis/Oxy_cropped', 'T2', 'an.nii')

# %%
LARC_df = p.dataframe(LARC_patientPaths, LARC_PatientNames, LARC_imagePaths, LARC_maskPaths)
Oxy_df = p.dataframe(Oxy_patientPaths, Oxy_PatientNames, Oxy_imagePaths, Oxy_maskPaths)

# %%
def rescale(dataframe, mask_filename):
    for i in range(len(dataframe['maskPaths'])):
        print(dataframe['maskPaths'][i])
        mask = sitk.ReadImage(dataframe['maskPaths'][i])
        mask_array = sitk.GetArrayFromImage(mask)
        imsize = np.shape(mask_array)
        mask_flatten = mask_array.flatten()
        
        for pixel in range(len(mask_flatten)):
            mask_flatten[pixel] = mask_flatten[pixel]/1000
        

        mask_rescaled = np.reshape(mask_flatten, imsize)
        mask_rescaled = mask_rescaled.astype(int)
        mask_rescaled = sitk.GetImageFromArray(mask_rescaled)
        
        os.remove(dataframe['maskPaths'][i])
        sitk.WriteImage(mask_rescaled, dataframe['maskPaths'][i])
        print(i)

# %%
rescale(Oxy_df, 'Manual_an.nii')
# Out:
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_103_PRE/Manual_an.nii
# 0
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_106_PRE/Manual_an.nii
# 1
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_108_PRE/Manual_an.nii
# 2
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_110_PRE/Manual_an.nii
# 3
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_111_PRE/Manual_an.nii
# 4
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_113_PRE/Manual_an.nii
# 5
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_115_PRE/Manual_an.nii
# 6
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_116_PRE/Manual_an.nii
# 7
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_118_PRE/Manual_an.nii
# 8
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_120_PRE/Manual_an.nii
# 9
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_121_PRE/Manual_an.nii
# 10
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_122_PRE/Manual_an.nii
# 11
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_123_PRE/Manual_an.nii
# 12
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_124_PRE/Manual_an.nii
# 13
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_125_PRE/Manual_an.nii
# 14
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_126_PRE/Manual_an.nii
# 15
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_127_PRE/Manual_an.nii
# 16
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_128_PRE/Manual_an.nii
# 17
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_130_PRE/Manual_an.nii
# 18
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_131_PRE/Manual_an.nii
# 19
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_133_PRE/Manual_an.nii
# 20
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_134_PRE/Manual_an.nii
# 21
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_138_PRE/Manual_an.nii
# 22
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_143_PRE/Manual_an.nii
# 23
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_144_PRE/Manual_an.nii
# 24
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_145_PRE/Manual_an.nii
# 25
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_146_PRE/Manual_an.nii
# 26
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_148_PRE/Manual_an.nii
# 27
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_149_PRE/Manual_an.nii
# 28
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_150_PRE/Manual_an.nii
# 29
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_153_PRE/Manual_an.nii
# 30
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_154_PRE/Manual_an.nii
# 31
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_155_PRE/Manual_an.nii
# 32
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_156_PRE/Manual_an.nii
# 33
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_157_PRE/Manual_an.nii
# 34
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_160_PRE/Manual_an.nii
# 35
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_162_PRE/Manual_an.nii
# 36
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_163_PRE/Manual_an.nii
# 37
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_164_PRE/Manual_an.nii
# 38
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_165_PRE/Manual_an.nii
# 39
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_166_PRE/Manual_an.nii
# 40
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_169_PRE/Manual_an.nii
# 41
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_170_PRE/Manual_an.nii
# 42
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_171_PRE/Manual_an.nii
# 43
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_172_PRE/Manual_an.nii
# 44
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_173_PRE/Manual_an.nii
# 45
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_174_PRE/Manual_an.nii
# 46
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_175_PRE/Manual_an.nii
# 47
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_176_PRE/Manual_an.nii
# 48
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_177_PRE/Manual_an.nii
# 49
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_179_PRE/Manual_an.nii
# 50
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_181_PRE/Manual_an.nii
# 51
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_184_PRE/Manual_an.nii
# 52
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_185_PRE/Manual_an.nii
# 53
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_186_PRE/Manual_an.nii
# 54
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_187_PRE/Manual_an.nii
# 55
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_188_PRE/Manual_an.nii
# 56
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_189_PRE/Manual_an.nii
# 57
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_190_PRE/Manual_an.nii
# 58
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_191_PRE/Manual_an.nii
# 59
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_192_PRE/Manual_an.nii
# 60
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_24_PRE/Manual_an.nii
# 61
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_27_PRE/Manual_an.nii
# 62
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_28_PRE/Manual_an.nii
# 63
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_29_PRE/Manual_an.nii
# 64
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_31_PRE/Manual_an.nii
# 65
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_32_PRE/Manual_an.nii
# 66
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_40_PRE/Manual_an.nii
# 67
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_41_PRE/Manual_an.nii
# 68
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_43_PRE/Manual_an.nii
# 69
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_44_PRE/Manual_an.nii
# 70
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_45_PRE/Manual_an.nii
# 71
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_46_PRE/Manual_an.nii
# 72
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_47_PRE/Manual_an.nii
# 73
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_48_PRE/Manual_an.nii
# 74
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_49_PRE/Manual_an.nii
# 75
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_50_PRE/Manual_an.nii
# 76
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_51_PRE/Manual_an.nii
# 77
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_52_PRE/Manual_an.nii
# 78
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_55_PRE/Manual_an.nii
# 79
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_56_PRE/Manual_an.nii
# 80
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_57_PRE/Manual_an.nii
# 81
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_58_PRE/Manual_an.nii
# 82
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_59_PRE/Manual_an.nii
# 83
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_61_PRE/Manual_an.nii
# 84
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_64_PRE/Manual_an.nii
# 85
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_65_PRE/Manual_an.nii
# 86
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_67_PRE/Manual_an.nii
# 87
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_68_PRE/Manual_an.nii
# 88
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_69_PRE/Manual_an.nii
# 89
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_72_PRE/Manual_an.nii
# 90
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_73_PRE/Manual_an.nii
# 91
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_74_PRE/Manual_an.nii
# 92
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_75_PRE/Manual_an.nii
# 93
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_77_PRE/Manual_an.nii
# 94
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_78_PRE/Manual_an.nii
# 95
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_79_PRE/Manual_an.nii
# 96
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_80_PRE/Manual_an.nii
# 97
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_83_PRE/Manual_an.nii
# 98
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_85_PRE/Manual_an.nii
# 99
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_87_PRE/Manual_an.nii
# 100
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_88_PRE/Manual_an.nii
# 101
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_89_PRE/Manual_an.nii
# 102
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_90_PRE/Manual_an.nii
# 103
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_91_PRE/Manual_an.nii
# 104
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_94_PRE/Manual_an.nii
# 105
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_95_PRE/Manual_an.nii
# 106
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_96_PRE/Manual_an.nii
# 107
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_97_PRE/Manual_an.nii
# 108
# /Volumes/HARDDISK/MasterThesis/Oxy_cropped/Oxytarget_99_PRE/Manual_an.nii
# 109
